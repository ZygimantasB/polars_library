# %%
import ibis

# %%
csv_file_path = r"C:\Users\Zygim\Downloads\archive (12)\invesment_in_building_construction.csv"

# %%
con = ibis.duckdb.connect()

# %%
con.raw_sql('PRAGMA threads=8')

# %%
table = con.read_csv(csv_file_path, table_name="email_thread_details")

# %%
table.execute()
# Out:
#         REF_DATE                           GEO           DGUID  \
# 0        2017-01                        Canada  2021A000011124
# 1        2017-01                        Canada  2021A000011124
# 2        2017-01                        Canada  2021A000011124
# 3        2017-01                        Canada  2021A000011124
# 4        2017-01                        Canada  2021A000011124
# ...          ...                           ...             ...
# 4173835  2024-09  Chilliwack, British Columbia    2021S0504930
# 4173836  2024-09  Chilliwack, British Columbia    2021S0504930
# 4173837  2024-09  Chilliwack, British Columbia    2021S0504930
# 4173838  2024-09  Chilliwack, British Columbia    2021S0504930
# 4173839  2024-09  Chilliwack, British Columbia    2021S0504930
#
#                              Type of structure          Type of work  \
# 0        Total residential and non-residential  Types of work, total
# ...

# %%
table.filter((table.GEO == 'Canada')) & (table.GEO == 'USA')
# Out:
# r0 := DatabaseTable: email_thread_details
#   REF_DATE          string
#   GEO               string
#   DGUID             string
#   Type of structure string
#   Type of work      string
#   Investment Value  string
#   UOM               string
#   UOM_ID            int64
#   SCALAR_FACTOR     string
#   SCALAR_ID         int64
#   VECTOR            string
#   COORDINATE        string
#   VALUE             int64
#   STATUS            string
#   SYMBOL            string
#   TERMINATED        string
#   DECIMALS          int64
#
# And(Equals(GEO, 'USA'), True): r0.GEO == 'USA' & True
