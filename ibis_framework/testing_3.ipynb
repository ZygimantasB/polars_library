# %%
import ibis

# %%
df_path = r"F:\Datasets\CSV datasets\internet_usage.csv"

# %%
con = ibis.connect("duckdb://:memory:")

# %%
futures_table = con.read_csv(df_path)

# %%
futures_table.head(5).execute()
# Out:
#      Country Name Country Code      2000        2001       2002       2003  \
# 0     Afghanistan          AFG        ..  0.00472257  0.0045614  0.0878913
# 1         Albania          ALB  0.114097    0.325798   0.390081     0.9719
# 2         Algeria          DZA  0.491706    0.646114    1.59164    2.19536
# 3  American Samoa          ASM        ..          ..         ..         ..
# 4         Andorra          AND   10.5388          ..    11.2605    13.5464
#
#        2004     2005     2006     2007  ...  2014  2015     2016     2017  \
# 0  0.105809  1.22415  2.10712      1.9  ...     7  8.26       11     13.5
# 1   2.42039  6.04389  9.60999  15.0361  ...  54.3  56.9     59.6     62.4
# 2   4.63448  5.84394  7.37598  9.45119  ...  29.5  38.2  42.9455  47.6911
# 3        ..       ..       ..       ..  ...    ..    ..       ..       ..
# 4    26.838  37.6058  48.9368    70.87  ...  86.1  87.9     89.7  91.5675
#
#       2018     2019     2020     2021     2022     2023
# ...

# %%
futures_table.count().execute()
# Out:
# 217

# %%
futures_table.select(
    'Country Name', 'Country Code', '2000'
).execute()
# Out:
#               Country Name Country Code       2000
# 0              Afghanistan          AFG         ..
# 1                  Albania          ALB   0.114097
# 2                  Algeria          DZA   0.491706
# 3           American Samoa          ASM         ..
# 4                  Andorra          AND    10.5388
# ..                     ...          ...        ...
# 212  Virgin Islands (U.S.)          VIR    13.8151
# 213     West Bank and Gaza          PSE    1.11131
# 214            Yemen, Rep.          YEM  0.0825004
# 215                 Zambia          ZMB   0.191072
# 216               Zimbabwe          ZWE   0.401434
#
# [217 rows x 3 columns]

# %%
futures_table.mutate(
    year_2000=ibis.case()
    .when(futures_table['2000'] == '..', None)
    .else_(futures_table['2000'])
    .end()
).execute()
# Out:
# C:\Users\Zygim\AppData\Local\Temp\ipykernel_39156\4286372317.py:2: FutureWarning: `case` is deprecated as of v10.0.0, removed in v11.0; use ibis.cases()
#   year_2000=ibis.case()
#               Country Name Country Code       2000        2001       2002  \
# 0              Afghanistan          AFG         ..  0.00472257  0.0045614
# 1                  Albania          ALB   0.114097    0.325798   0.390081
# 2                  Algeria          DZA   0.491706    0.646114    1.59164
# 3           American Samoa          ASM         ..          ..         ..
# 4                  Andorra          AND    10.5388          ..    11.2605
# ..                     ...          ...        ...         ...        ...
# 212  Virgin Islands (U.S.)          VIR    13.8151     18.3758    27.4944
# 213     West Bank and Gaza          PSE    1.11131     1.83685    3.10009
# 214            Yemen, Rep.          YEM  0.0825004   0.0908025   0.518796
# ...

# %%
# Out:
# 1236
