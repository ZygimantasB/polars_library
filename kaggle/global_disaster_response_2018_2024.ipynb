# %%
import polars as pl
import polars.selectors as cs

import altair as alt
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_path = r'/Users/zygimantas/Documents/DataSets/global_disaster_response_2018_2024 (1).csv'

# %%
df = pl.read_csv(df_path)

# %%
df
# Out:
# shape: (50_000, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬──────────┬───────────┐
# │ date      ┆ country   ┆ disaster_ ┆ severity_ ┆ … ┆ response_ ┆ recovery_ ┆ latitude ┆ longitude │
# │ ---       ┆ ---       ┆ type      ┆ index     ┆   ┆ efficienc ┆ days      ┆ ---      ┆ ---       │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ y_score   ┆ ---       ┆ f64      ┆ f64       │
# │           ┆           ┆ str       ┆ f64       ┆   ┆ ---       ┆ i64       ┆          ┆           │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆           ┆          ┆           │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪══════════╪═══════════╡
# │ 2021-01-3 ┆ Brazil    ┆ Earthquak ┆ 5.99      ┆ … ┆ 83.21     ┆ 67        ┆ -30.613  ┆ -122.557  │
# │ 1         ┆           ┆ e         ┆           ┆   ┆           ┆           ┆          ┆           │
# │ 2018-12-2 ┆ Brazil    ┆ Extreme   ┆ 6.53      ┆ … ┆ 96.18     ┆ 55        ┆ 10.859   ┆ -159.194  │
# │ 3         ┆           ┆ Heat      ┆           ┆   ┆           ┆           ┆          ┆           │
# │ 2020-08-1 ┆ India     ┆ Hurricane ┆ 1.55      ┆ … ┆ 60.4      ┆ 22        ┆ 0.643    ┆ -160.978  │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆          ┆           │
# │ 2022-09-1 ┆ Indonesia ┆ Extreme   ┆ 4.55      ┆ … ┆ 86.41     ┆ 47        ┆ -33.547  ┆ 30.35     │
# │ 5         ┆           ┆ Heat      ┆           ┆   ┆           ┆           ┆          ┆           │
# │ 2022-09-2 ┆ United    ┆ Wildfire  ┆ 3.8       ┆ … ┆ 72.81     ┆ 42        ┆ -19.17   ┆ -117.137  │
# │ 8         ┆ States    ┆           ┆           ┆   ┆           ┆           ┆          ┆           │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …        ┆ …         │
# │ 2019-05-1 ┆ Chile     ┆ Landslide ┆ 5.5       ┆ … ┆ 94.27     ┆ 55        ┆ 12.976   ┆ -25.68    │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆           ┆          ┆           │
# │ 2020-10-3 ┆ United    ┆ Wildfire  ┆ 7.76      ┆ … ┆ 95.46     ┆ 76        ┆ 57.265   ┆ -147.346  │
# │ 0         ┆ States    ┆           ┆           ┆   ┆           ┆           ┆          ┆           │
# │ 2019-04-2 ┆ Turkey    ┆ Flood     ┆ 4.9       ┆ … ┆ 86.67     ┆ 47        ┆ 15.217   ┆ -27.856   │
# │ 7         ┆           ┆           ┆           ┆   ┆           ┆           ┆          ┆           │
# │ 2022-10-0 ┆ Greece    ┆ Storm     ┆ 3.35      ┆ … ┆ 84.75     ┆ 32        ┆ -44.002  ┆ 1.923     │
# │ 9         ┆           ┆ Surge     ┆           ┆   ┆           ┆           ┆          ┆           │
# │ 2023-01-1 ┆ South     ┆ Drought   ┆ 5.03      ┆ … ┆ 97.16     ┆ 50        ┆ 13.084   ┆ -81.048   │
# │ 2         ┆ Africa    ┆           ┆           ┆   ┆           ┆           ┆          ┆           │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴──────────┴───────────┘
