# %%
import polars as pl
import polars.selectors as cs

import altair as alt
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_path = r'/Users/zygimantas/Documents/DataSets/Latest 2025 movies Datasets.csv'

# %%
df = pl.read_csv(df_path)

# %%
df
# Out:
# shape: (10_000, 8)
# ┌──────┬─────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │      ┆ title       ┆ release_da ┆ original_l ┆ popularity ┆ vote_count ┆ vote_avera ┆ overview   │
# │ ---  ┆ ---         ┆ te         ┆ anguage    ┆ ---        ┆ ---        ┆ ge         ┆ ---        │
# │ i64  ┆ str         ┆ ---        ┆ ---        ┆ f64        ┆ i64        ┆ ---        ┆ str        │
# │      ┆             ┆ str        ┆ str        ┆            ┆            ┆ f64        ┆            │
# ╞══════╪═════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ 0    ┆ Our Fault   ┆ 2025-10-15 ┆ es         ┆ 1096.6654  ┆ 302        ┆ 7.869      ┆ Jenna and  │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ Lion's     │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ wedding    │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ bring…     │
# │ 1    ┆ Inside      ┆ 2025-10-14 ┆ pl         ┆ 384.322    ┆ 27         ┆ 6.593      ┆ In the     │
# │      ┆ Furioza     ┆            ┆            ┆            ┆            ┆            ┆ wake of    │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ murder,    │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ new Fur…   │
# │ 2    ┆ Captain     ┆ 2025-07-11 ┆ en         ┆ 370.1091   ┆ 15         ┆ 5.0        ┆ In the     │
# │      ┆ Hook - The  ┆            ┆            ┆            ┆            ┆            ┆ aftermath  │
# │      ┆ Cursed      ┆            ┆            ┆            ┆            ┆            ┆ of a       │
# │      ┆ Tide…       ┆            ┆            ┆            ┆            ┆            ┆ devastat…  │
# │ 3    ┆ War of the  ┆ 2025-07-29 ┆ en         ┆ 327.876    ┆ 642        ┆ 4.4        ┆ Will       │
# │      ┆ Worlds      ┆            ┆            ┆            ┆            ┆            ┆ Radford is │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ a top      │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ analyst …  │
# │ 4    ┆ The         ┆ 2025-09-03 ┆ en         ┆ 284.0186   ┆ 1065       ┆ 6.972      ┆ Paranormal │
# │      ┆ Conjuring:  ┆            ┆            ┆            ┆            ┆            ┆ investigat │
# │      ┆ Last Rites  ┆            ┆            ┆            ┆            ┆            ┆ ors Ed an… │
# │ …    ┆ …           ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 9995 ┆ Mishka      ┆ 2017-10-22 ┆ en         ┆ 4.0294     ┆ 2          ┆ 6.0        ┆ Mishka     │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ tells the  │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ story of a │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ co…        │
# │ 9996 ┆ The Life    ┆ 1968-01-03 ┆ en         ┆ 4.7699     ┆ 0          ┆ 0.0        ┆ null       │
# │      ┆ and Flight  ┆            ┆            ┆            ┆            ┆            ┆            │
# │      ┆ of the Rev… ┆            ┆            ┆            ┆            ┆            ┆            │
# │ 9997 ┆ Surcos de   ┆ 1950-06-23 ┆ es         ┆ 3.9765     ┆ 0          ┆ 0.0        ┆ Melodrama  │
# │      ┆ sangre      ┆            ┆            ┆            ┆            ┆            ┆ that tells │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ the trage… │
# │ 9998 ┆ The         ┆ 1925-11-10 ┆ en         ┆ 4.372      ┆ 0          ┆ 0.0        ┆ Mark King  │
# │      ┆ Everlasting ┆            ┆            ┆            ┆            ┆            ┆ comes to   │
# │      ┆ Whisper     ┆            ┆            ┆            ┆            ┆            ┆ the aid of │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ …          │
# │ 9999 ┆ Somnambulis ┆ 1978-09-18 ┆ es         ┆ 4.5995     ┆ 7          ┆ 4.6        ┆ Ana works  │
# │      ┆ ts          ┆            ┆            ┆            ┆            ┆            ┆ side by    │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ side with  │
# │      ┆             ┆            ┆            ┆            ┆            ┆            ┆ he…        │
# └──────┴─────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴────────────┘
