# %%
import polars as pl
import polars.selectors as cs

import altair as alt
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_path = r'/mnt/samsung/Datasets/csv_data/music_streaming_habits_2026.csv'

# %%
df = pl.read_csv(df_path)

# %%
df
# Out:
# shape: (4_000, 15)
# ┌─────────────┬─────┬───────────┬────────────┬───┬────────────┬──────────┬────────────┬────────────┐
# │ listener_id ┆ age ┆ country   ┆ platform   ┆ … ┆ discover_w ┆ top_mood ┆ uses_offli ┆ podcasts_t │
# │ ---         ┆ --- ┆ ---       ┆ ---        ┆   ┆ eekly_user ┆ ---      ┆ ne_mode    ┆ oo         │
# │ i64         ┆ i64 ┆ str       ┆ str        ┆   ┆ ---        ┆ str      ┆ ---        ┆ ---        │
# │             ┆     ┆           ┆            ┆   ┆ bool       ┆          ┆ bool       ┆ bool       │
# ╞═════════════╪═════╪═══════════╪════════════╪═══╪════════════╪══════════╪════════════╪════════════╡
# │ 1           ┆ 24  ┆ Australia ┆ Apple      ┆ … ┆ false      ┆ Sleep    ┆ false      ┆ true       │
# │             ┆     ┆           ┆ Music      ┆   ┆            ┆          ┆            ┆            │
# │ 2           ┆ 21  ┆ Germany   ┆ Spotify    ┆ … ┆ true       ┆ Workout  ┆ true       ┆ true       │
# │ 3           ┆ 32  ┆ Japan     ┆ Amazon     ┆ … ┆ true       ┆ Sad      ┆ false      ┆ true       │
# │             ┆     ┆           ┆ Music      ┆   ┆            ┆          ┆            ┆            │
# │ 4           ┆ 39  ┆ Japan     ┆ Apple      ┆ … ┆ true       ┆ Sad      ┆ true       ┆ false      │
# │             ┆     ┆           ┆ Music      ┆   ┆            ┆          ┆            ┆            │
# │ 5           ┆ 23  ┆ India     ┆ Spotify    ┆ … ┆ true       ┆ Workout  ┆ true       ┆ true       │
# │ …           ┆ …   ┆ …         ┆ …          ┆ … ┆ …          ┆ …        ┆ …          ┆ …          │
# │ 3996        ┆ 26  ┆ France    ┆ Spotify    ┆ … ┆ false      ┆ Workout  ┆ true       ┆ false      │
# │ 3997        ┆ 35  ┆ Germany   ┆ YouTube    ┆ … ┆ true       ┆ Sad      ┆ false      ┆ true       │
# │             ┆     ┆           ┆ Music      ┆   ┆            ┆          ┆            ┆            │
# │ 3998        ┆ 43  ┆ India     ┆ Apple      ┆ … ┆ false      ┆ Happy    ┆ true       ┆ true       │
# │             ┆     ┆           ┆ Music      ┆   ┆            ┆          ┆            ┆            │
# │ 3999        ┆ 26  ┆ India     ┆ Apple      ┆ … ┆ false      ┆ Happy    ┆ false      ┆ false      │
# │             ┆     ┆           ┆ Music      ┆   ┆            ┆          ┆            ┆            │
# │ 4000        ┆ 24  ┆ UK        ┆ Spotify    ┆ … ┆ true       ┆ Workout  ┆ false      ┆ false      │
# └─────────────┴─────┴───────────┴────────────┴───┴────────────┴──────────┴────────────┴────────────┘
